# %%
# Importations des bibliothèques nécessaires
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import (
    classification_report, 
    confusion_matrix, 
    ConfusionMatrixDisplay,
    f1_score, 
    precision_recall_curve,
    roc_auc_score
)
import joblib 

# Configuration de la graine aléatoire
RANDOM_STATE = 42
# Out:
# Pipeline optimisé chargé avec succès.
# Jeu de données de test final chargé. Taille : (10000, 24)

# %%
#
final_pipeline = joblib.load("../models/best_model.pkl")
